# %% [markdown]
# **Project Name** - FedEx Logistics Performance Analysis

# %% [markdown]
# **Project Type** - Exploratory Data Analysis
# **Contribution**- Individual
#  **Name** - Y Suchitra

# %% [markdown]
# **Project Summary**

# %% [markdown]
# **Optimizing FedEx Logistics Through Data Analysis**
#
# In an increasingly interconnected global economy, FedEx Logistics serves as a backbone for supply chain management across multiple industries and regions. With the surge of eCommerce and the growing complexity of international distribution, efficiency in logistics has become essential for maintaining a competitive advantage. This project leverages data from FedEx Logistics to uncover operational insights that can improve shipment processes, reduce costs, and elevate customer satisfaction.
#
# The dataset provides a wide-ranging view of logistics performance, incorporating details such as shipment modes, origin and destination countries, vendor activity, line item values, package weights, freight costs, and records of delivery delays. Such comprehensive information allows for both high-level trend identification and granular performance evaluation.
#
# **Univariate Analysis explores:**
#
# 1.   Shipment counts by country
# 2.   Distribution of shipment modes
# 1.   Average freight costs
# 2.   Line item quantity patterns
# 1.   Weight distributions
# 2.   Vendors with the highest order volumes
#
# **Bi-variate Analysis further examines relationships between variables, such as:**
#
# 1.   Average weight across shipment modes
# 2.   Delivery delays by mode of transport
# 1.   Shipment volumes over time
# 2.   Line item value distribution across different shipment methods

# %% [markdown]
# **GitHub Link -**

# %% [markdown]
# **Problem Statement**

# %% [markdown]
# **Problem Statements for FedEx Logistics Performance Analysis**
#
# 1.   High Dependency on a Single Shipping Method
# 2.   Inconsistent Correlation Between Cost and Service
# 1.   Significant and Costly Delivery Delays
# 2.   Inefficient Cost Structure
# 1.   Geographic Concentration of High-Cost Shipments
# 2.   Unpredictable and Volatile Freight Costs
# 1.   Suboptimal Vendor Strategy and Performance Management

# %% [markdown]
# **Define Your Business Objective?**

# %% [markdown]
# The business objective is to optimize FedEx Logistics' global supply chain operations by leveraging data insights.This will support FedEx in maintaining a competitive edge in the growing eCommerce and global distribution landscape while delivering value to both the company and its customers.Main Business Objectives are listed below:
#
# 1.   Improve delivery efficiency
# 2.   Enhance customer satisfaction
# 1.   Identify bottlenecks
# 2.   Streamline processes
# 1.   Ensure timely Deliveries

# %% [markdown]
# **General Guidelines : -**

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# **Let's Begin !**

# %% [markdown]
# 1.**Know Your Data**

# %% [markdown]
# Import Libraries

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import matplotlib.patches as patches
import matplotlib.ticker as mtick
import matplotlib.lines as lines
import matplotlib.image as mpimg
import matplotlib.colors as mcolors
import warnings
warnings.filterwarnings('ignore') #filter warning to ingnore
pd.set_option('display.max_rows', 500)  # Show all rows
pd.set_option('display.max_columns', 33)  # Show all columns

# %%
import matplotlib.pyplot as plt
from matplotlib import ticker as mtick

# %%
import os

print(os.getcwd())
# Out:
# /content

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'fedex.xlsx', 'sample_data']

# %%
import pandas as pd

fed_ex_raw = pd.read_excel("fedex.xlsx")
fed_ex_raw.head()
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #       Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  C魌e d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85       Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  C魌e d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50       Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55       Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 0   PMO - US  Direct Drop              EXW           Air
# 1   PMO - US  Direct Drop              EXW           Air
# 2   PMO - US  Direct Drop              FCA           Air
# 3   PMO - US  Direct Drop              EXW           Air
# 4   PMO - US  Direct Drop              EXW           Air
#
#   PQ First Sent to Client Date PO Sent to Vendor Date Scheduled Delivery Date  \
# 0               Pre-PQ Process      Date Not Captured              2006-06-02
# ...

# %% [markdown]
# Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
fed_ex_raw.shape
# Out:
# (10324, 33)

# %% [markdown]
# Dataset Information

# %%
# Dataset Info
fed_ex_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          10324 non-null  object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              10324 non-null  object
#  9   Shipment Mode                 9964 non-null   object
#  10  PQ First Sent to Client Date  10324 non-null  object
#  11  PO Sent to Vendor Date        10324 non-null  object
# ...

# %% [markdown]
# Duplicate Values

# %%
# Dataset Duplicate Value Count
fed_ex_raw.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(fed_ex_raw.isnull().sum())
# Out:
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                    360
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                          1736
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# Line Item Quantity                 0
# ...

# %%
# Visualizing the missing values
# Define a color palette for the chart bars
palette = ['#4d148c', '#ff6600', '#000000', '#ffffff']

# Calculate the number of missing values for each column in the dataset and sort in descending order
missing_data = fed_ex_raw.isnull().sum()
missing_data = missing_data[missing_data > 0].sort_values(ascending=False)

# Set up the figure and axis with specified size for readability
fig, ax = plt.subplots(1, 1, figsize=(5, 3))

# Plot the missing data counts as a bar chart
bars = ax.bar(missing_data.index, missing_data.values, color=palette)

# Rotate x-axis labels for better readability and align them to the right
ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha='right')


# Adjust layout for proper spacing and element display
plt.tight_layout()

# Display the final plot
plt.show()

# %% [markdown]
# What did you know about your dataset?

# %% [markdown]
# Fedex dataset consists of 10,324 entries and 33 columns, including various fields related to procurement and shipment details, such as IDs, project codes, purchase orders, and shipping numbers. It also captures logistical details like shipment modes, vendor terms, and delivery dates. Key numerical fields include line item quantities, prices, and freight costs. Some columns contain missing data, such as "Shipment Mode" and "Dosage," while most others are complete. Additionally, certain fields like "Weight (Kilograms)" and "Freight Cost (USD)" are stored as objects but may need conversion for numerical analysis. Overall, it’s a detailed dataset suited for procurement and supply chain analysis.

# %% [markdown]
# 2.**Understanding Variables**

# %%
# Dataset Columns
fed_ex_raw.columns
# Out:
# Index(['ID', 'Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #', 'Country',
#        'Managed By', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode',
#        'PQ First Sent to Client Date', 'PO Sent to Vendor Date',
#        'Scheduled Delivery Date', 'Delivered to Client Date',
#        'Delivery Recorded Date', 'Product Group', 'Sub Classification',
#        'Vendor', 'Item Description', 'Molecule/Test Type', 'Brand', 'Dosage',
#        'Dosage Form', 'Unit of Measure (Per Pack)', 'Line Item Quantity',
#        'Line Item Value', 'Pack Price', 'Unit Price', 'Manufacturing Site',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)'],
#       dtype='object')

# %%
# Dataset Describe
fed_ex_raw.describe()
# Out:
#                  ID        Scheduled Delivery Date  \
# count  10324.000000                          10324
# mean   51098.968229  2011-10-04 15:30:28.593568512
# min        1.000000            2006-05-02 00:00:00
# 25%    12795.750000            2009-09-08 00:00:00
# 50%    57540.500000            2011-12-05 00:00:00
# 75%    83648.250000            2013-12-23 00:00:00
# max    86823.000000            2015-12-31 00:00:00
# std    31944.332496                            NaN
#
#             Delivered to Client Date         Delivery Recorded Date  \
# count                          10324                          10324
# mean   2011-09-28 14:56:34.963192576  2011-10-01 12:33:28.523827968
# min              2006-05-02 00:00:00            2006-05-02 00:00:00
# 25%              2009-09-01 00:00:00            2009-09-01 00:00:00
# 50%              2011-11-25 00:00:00            2011-11-25 00:00:00
# 75%              2013-12-23 00:00:00            2014-01-13 00:00:00
# ...

# %% [markdown]
# **Variables Description**

# %% [markdown]
# *   **ID:** A unique identifier for each record or line item in the dataset.
# *   **Project Code:** An identifier for the specific project associated with the shipment.
# *   **PQ #:** The number for the Purchase Quote, a preliminary request for goods or services.
# *   **PO / SO #:** The number for the Purchase Order or Sales Order, a commercial document confirming an order.
# *   **ASN/DN #:** The number for the Advanced Shipping Notice or Delivery Note.
# *   **Country:** The country where the products were delivered.
# *   **Managed By:** The organization or entity managing the shipment.
# *   **Fulfill Via:** Specifies the method of fulfillment, such as "Direct Drop" or "From RDC" (Regional Distribution Center).
# *   **Vendor INCO Term:** The Incoterm (International Commercial Term) for the vendor agreement, which defines the responsibilities of the buyer and seller.
# *   **Shipment Mode:** The method of transport used for the shipment (e.g., Air, Truck).
# *   **PQ First Sent to Client Date:** The date the initial purchase quote was sent to the client.
# *   **PO Sent to Vendor Date:** The date the purchase order was sent to the vendor.
# *   **Scheduled Delivery Date:** The planned date for the delivery to the client.
# *   **Delivered to Client Date:** The actual date the shipment was delivered to the client.
# *   **Delivery Recorded Date:** The date the delivery was officially recorded in the system.
# *   **Product Group:** A high-level category for the product, such as 'ARV' or 'HRDT'.
# *   **Sub Classification:** A more specific classification of the product (e.g., 'Adult', 'Pediatric', 'HIV test').
# *   **Vendor:** The name of the company that supplied the goods.
# *   **Item Description:** A detailed description of the product in the shipment.
# *   **Molecule/Test Type:** The specific molecule or test type of the product.
# *   **Brand:** The brand name of the product.
# *   **Dosage:** The dosage strength of the medication (e.g., '150mg').
# *   **Dosage Form:** The physical form of the medication (e.g., 'Tablet', 'Oral suspension').
# *   **Unit of Measure (Per Pack):** The number of units contained in each pack.
# *   **Line Item Quantity:** The total number of units shipped for that line item.
# *   **Line Item Value:** The total monetary value of the line item.
# *   **Pack Price:** The price per pack of the product.
# *   **Unit Price:** The price per individual unit.
# *   **Manufacturing Site:** The location where the product was manufactured.
# *   **First Line Designation:** A categorical variable indicating if the product is a first-line treatment.
# *   **Weight (Kilograms):** The total weight of the shipment in kilograms. This column contains both numerical and text values, such as "Weight Captured Separately."
# *   **Freight Cost (USD):** The cost of shipping the products in US dollars. This also contains text values like "Freight Included in Commodity Cost."
# *   **Line Item Insurance (USD):** The insurance cost for the specific line item in US dollars.

# %% [markdown]
# Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in fed_ex_raw.columns:
    print(f"{column} : {len(fed_ex_raw[column].unique())}")
# Out:
# ID : 10324
# Project Code : 142
# PQ # : 1237
# PO / SO # : 6233
# ASN/DN # : 7030
# Country : 43
# Managed By : 4
# Fulfill Via : 2
# Vendor INCO Term : 8
# Shipment Mode : 5
# PQ First Sent to Client Date : 765
# PO Sent to Vendor Date : 897
# Scheduled Delivery Date : 2006
# Delivered to Client Date : 2093
# Delivery Recorded Date : 2042
# Product Group : 5
# Sub Classification : 6
# Vendor : 73
# Item Description : 184
# Molecule/Test Type : 86
# Brand : 48
# Dosage : 55
# Dosage Form : 17
# Unit of Measure (Per Pack) : 31
# Line Item Quantity : 5065
# Line Item Value : 8741
# Pack Price : 1175
# Unit Price : 183
# Manufacturing Site : 88
# First Line Designation : 2
# Weight (Kilograms) : 4688
# Freight Cost (USD) : 6733
# Line Item Insurance (USD) : 6723

# %% [markdown]
# **3. Data Wrangling**

# %%
fed_ex_curated = fed_ex_raw[[
    'Country',
    'Managed By',
    'Fulfill Via',
    'Shipment Mode',
    'PQ First Sent to Client Date',
    'PO Sent to Vendor Date',
    'Scheduled Delivery Date',
    'Delivered to Client Date',
    'Delivery Recorded Date',
    'Line Item Quantity',
    'Line Item Value',
    'Weight (Kilograms)',
    'Freight Cost (USD)',
    'Vendor',
    'Line Item Insurance (USD)'
]]

# Drop duplicates while keeping the first occurrence
fed_ex_curated.drop_duplicates(inplace=True)

# Convert to datetime, handling errors
date_columns = ['PQ First Sent to Client Date', 'PO Sent to Vendor Date',
                'Scheduled Delivery Date', 'Delivered to Client Date',
                'Delivery Recorded Date']
for col in date_columns:
    fed_ex_curated[col] = pd.to_datetime(fed_ex_curated[col], errors='coerce')

# Convert to numeric type, handling errors and invalid values
numeric_columns = ['Line Item Quantity', 'Line Item Value', 'Weight (Kilograms)',
                   'Freight Cost (USD)', 'Line Item Insurance (USD)']
for col in numeric_columns:
    fed_ex_curated[col] = pd.to_numeric(fed_ex_curated[col], errors='coerce')

# Geting the most common value
shipment_mode_mode = fed_ex_curated['Shipment Mode'].mode()[0]

# Filling with the mode
fed_ex_curated['Shipment Mode'].fillna(shipment_mode_mode, inplace=True)

# Filling missing Line Item insurance values with 0
fed_ex_curated['Line Item Insurance (USD'] = fed_ex_curated['Line Item Insurance (USD)'].fillna(0)

# Standardizing country names with proper case handling
fed_ex_curated['Country'] = fed_ex_curated['Country'].str.strip().str.lower()

# Creating a new column for year as categorical for further analysis
fed_ex_curated['Delivery Year'] = fed_ex_curated['Delivered to Client Date'].dt.year

# Calculate delivery lead time in days for further analysis.
fed_ex_curated['Lead Time Days'] = (fed_ex_curated['Delivered to Client Date'] - fed_ex_curated['Scheduled Delivery Date']).dt.days

# %% [markdown]
# What all manipulations have you done and insights you found?

# %% [markdown]
# I began by selecting the most relevant columns from the dataset for our logistics analysis. I then cleaned the data by removing duplicate entries and ensuring all date and numeric columns were converted to their proper formats, coercing any errors to maintain data integrity. To handle missing values, I filled in the most common shipment mode and set missing insurance costs to zero. I also standardized country names to lowercase to ensure consistency. Finally, I engineered two new features: a 'Delivery Year' for time-based analysis and a 'Lead Time Days' column to quantitatively measure whether deliveries were early or late, which is crucial for pinpointing delays and assessing our on-time performance.

# %% [markdown]
# **4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables**

# %% [markdown]
# Chart - 1

# %%
# Chart - 1: Shipment Volume by Country (Top 5)
fig, ax = plt.subplots(1, 1, figsize=(12, 6))

# Get top 5 countries by shipment count
top_countries = fed_ex_curated['Country'].value_counts().nlargest(5)
country_names = top_countries.index.tolist()
shipment_counts = top_countries.values.tolist()

# Create bar plot with enhanced styling
bars = sns.barplot(
    x=country_names,
    y=shipment_counts,
    palette=palette,
    alpha=0.8,
    edgecolor='black',
    linewidth=1
)

# Add value labels on top of each bar
for i, (country, count) in enumerate(zip(country_names, shipment_counts)):
    plt.text(i, count + 5, f'{count:,}',
             ha='center', va='bottom', fontweight='bold', fontsize=10)

# Customize titles and labels for better understanding
plt.title('Top 5 Countries by Shipment Volume\n', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Country', fontsize=12, fontweight='bold', labelpad=10)
plt.ylabel('Number of Shipments', fontsize=12, fontweight='bold', labelpad=10)

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45, ha='right')

# Add grid for easier value reading
plt.grid(axis='y', alpha=0.3, linestyle='--')

# Remove spines for cleaner look
sns.despine(left=True)

# Adjust layout and display
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The count plot clearly shows shipment volumes by country for easy comparison.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# South African countries lead in shipments, indicating strong trade, with Nigeria and Côte d'Ivoire also showing significant activity.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive impact:** Focus on high-volume countries can improve logistics and boost revenue.
#
# **Negative Insight:** Relying too much on specific countries can risk supply chain disruptions if issues arise there.

# %% [markdown]
# Chart - 2

# %%
# Chart - 2: Distribution of Shipment Modes
fig, ax = plt.subplots(figsize=(7, 7))

# Calculate shipment mode percentages
shipment_mode_counts = fed_ex_curated['Shipment Mode'].value_counts()
total_shipments = len(fed_ex_curated)
percentages = (shipment_mode_counts / total_shipments) * 100

# Create explode effect for the largest segment
explode = [0.1 if i == 0 else 0 for i in range(len(shipment_mode_counts))]

# Plot the pie chart with enhanced styling
wedges, texts, autotexts = ax.pie(
    shipment_mode_counts.values,
    labels=shipment_mode_counts.index,
    colors=palette,
    explode=explode,
    autopct='%.0f%%',
    startangle=90,
    textprops={'fontsize': 11, 'fontweight': 'bold'},
    wedgeprops={'edgecolor': 'black', 'linewidth': 1, 'alpha': 0.9}
)

# Enhance percentage labels
for autotext in autotexts:
    autotext.set_color('green')
    autotext.set_fontweight('bold')
    autotext.set_fontsize(10)

# Add title with clear explanation
plt.title('Distribution of Shipment Methods\n',
          fontsize=16, fontweight='bold', pad=20, color='#2E4053')

# Add legend with count information in bottom right corner
legend_labels = [f'{mode}: {count:,} shipments ({percent:.1f}%)'
                for mode, count, percent in zip(shipment_mode_counts.index,
                                               shipment_mode_counts.values,
                                               percentages)]

# Position legend in bottom right corner
plt.legend(wedges, legend_labels,
          title="Shipment Methods",
          loc='lower right',
          bbox_to_anchor=(1.3, 0),
          fontsize=9,
          title_fontsize=10)

# Adjust layout to make space for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart shows the distribution of shipment modes clearly, making it easy to see which mode is most used.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Over 63% of shipments are by air, 27% by truck, 5% by air charter, and only 4% by ocean. This indicates a strong preference for fast delivery.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:** The insights can help improve logistics strategies and negotiate better rates for air shipments.
#
# **Negative Insight:** Relying too much on air transport may lead to higher costs and missed opportunities for cheaper ocean freight options.

# %% [markdown]
# Chart - 3

# %%
# Chart - 3: Distribution of Freight Costs
fig, ax = plt.subplots(1, 1, figsize=(12, 7))

# Plotting the histogram of the Freight Cost (USD)
sns.histplot(x='Freight Cost (USD)', data=fed_ex_curated, kde=True, bins=30, color='#ff6600', alpha=0.7)

# Calculate key statistics for annotations
mean_cost = fed_ex_curated['Freight Cost (USD)'].mean()
median_cost = fed_ex_curated['Freight Cost (USD)'].median()
std_cost = fed_ex_curated['Freight Cost (USD)'].std()
total_shipments = len(fed_ex_curated)

# Add vertical lines for mean and median
plt.axvline(mean_cost, color='red', linestyle='--', linewidth=2, label=f'Mean: ${mean_cost:,.2f}')

# Customize titles and labels for better understanding
plt.title('Distribution of Freight Costs\n', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Freight Cost (USD)', fontsize=12, fontweight='bold', labelpad=10)
plt.ylabel('Number of Shipments', fontsize=12, fontweight='bold', labelpad=10)

# Format x-axis to show dollar amounts
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))

# Add grid for easier value reading
plt.grid(axis='y', alpha=0.3, linestyle='--')

# Add legend
plt.legend(loc='upper right', fontsize=10)

sns.despine(left=True)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram shows the distribution of freight costs, making it easy to see trends and identify high and low cost ranges.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The average freight cost is 11, 076.78, with most shipments costing less. There are few shipments over 50,000, indicating high costs are rare.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:** Insights can help optimize logistics and reduce costs.
#
# **Negative Growth:** Relying on a few high-value shipments could be risky, and many low-cost shipments might not be profitable enough.

# %% [markdown]
# Chart - 4

# %%
# Chart - 4: Distribution of Line Item Quantities
fig, ax = plt.subplots(1, 1, figsize=(12, 6))

# Plotting the histogram of the Line Item Quantity
sns.histplot(x='Line Item Quantity', data=fed_ex_curated, kde=True, bins=30, color='#4d148c', alpha=0.7)

# Identify the most common quantity range
mode_quantity = fed_ex_curated['Line Item Quantity'].mode()[0]

# Customize titles and labels for better understanding
plt.title('Distribution of Line Item Quantities per Shipment\n', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Number of Units per Line Item', fontsize=12, fontweight='bold', labelpad=10)
plt.ylabel('Frequency (Number of Shipments)', fontsize=12, fontweight='bold', labelpad=10)

# Format x-axis for better readability
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{x:,.0f}'))

# Add grid for easier value reading
plt.grid(axis='y', alpha=0.3, linestyle='--')

# Add legend
plt.legend(loc='upper right', fontsize=10)

# Remove spines for cleaner look
sns.despine(left=True)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram shows the distribution of Line Item Quantities, helping to visualize common order sizes.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It highlights the most frequently ordered quantities, revealing patterns in shipment sizes.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact: **Helps improve inventory management by identifying common order sizes.
#
# **Negative Growth: **A focus on low quantities may indicate missed opportunities for larger, more profitable orders.

# %% [markdown]
# Chart - 5

# %%
# Chart - 5: Distribution of Shipment Weights (Without Outliers)
fig, ax = plt.subplots(1, 1, figsize=(14, 8))

# Plotting the boxplot of the shipment weights without outliers
boxplot = sns.boxplot(x='Weight (Kilograms)', data=fed_ex_curated, ax=ax, color='#ffffff',
                     showfliers=False, width=0.6)

# Calculate key statistics for annotations
weight_stats = fed_ex_curated['Weight (Kilograms)'].describe()
q1 = weight_stats['25%']
median = weight_stats['50%']
q3 = weight_stats['75%']
iqr = q3 - q1
mean_weight = weight_stats['mean']
total_shipments = len(fed_ex_curated)

# Add mean line
plt.axvline(mean_weight, color='red', linestyle='--', linewidth=2,
           label=f'Mean: {mean_weight:.1f} kg')

# Add text annotations for key statistics
text_props = dict(boxstyle="round,pad=0.3", facecolor="yellow", alpha=0.7)

# Format x-axis for better readability
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{x:,.0f} kg'))

# Add grid for easier value reading
plt.grid(axis='x', alpha=0.3, linestyle='--')

# Add legend
plt.legend(loc='upper right', fontsize=10)

# Remove y-axis labels for boxplot clarity
plt.yticks([])

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The box plot was chosen to show the distribution of shipment weights clearly.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows limited variability in shipment weights, indicating most weights fall within a narrow range.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:** Predictable weights can improve logistics efficiency.
#
# **Negative Insight:** Limited data variability may suggest data issues or a lack of product diversity, which could hinder growth opportunities.

# %% [markdown]
# Chart - 6

# %%
# Chart - 6: Top 5 Vendors by Shipment Volume
fig, ax = plt.subplots(figsize=(12, 7))

# Get top 5 vendors by shipment count
top_vendors = fed_ex_curated['Vendor'].value_counts().nlargest(5)
vendor_names = top_vendors.index.tolist()
shipment_counts = top_vendors.values.tolist()

# Create bar plot with enhanced styling
bars = sns.barplot(
    x=vendor_names,
    y=shipment_counts,
    palette=palette,
    alpha=0.8,
    edgecolor='black',
    linewidth=1
)

# Add value labels on top of each bar
for i, (vendor, count) in enumerate(zip(vendor_names, shipment_counts)):
    plt.text(i, count + 5, f'{count:,}',
             ha='center', va='bottom', fontweight='bold', fontsize=11)

# Customize titles and labels for better understanding
plt.title('Top 5 Vendors by Shipment Volume\n', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Vendor', fontsize=12, fontweight='bold', labelpad=10)
plt.ylabel('Number of Shipments', fontsize=12, fontweight='bold', labelpad=10)

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45, ha='right')

# Add grid for easier value reading
plt.grid(axis='y', alpha=0.3, linestyle='--')

# Remove spines for cleaner look
sns.despine(left=True)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar chart because it clearly shows the number of orders from different vendors, making comparisons easy.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# SCMS from RDC has over 5000 orders, far more than other vendors like Ogenics and S. BUYS WHOLESALER, which have around 1000

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:** Focusing on SCMS can improve procurement strategies and possibly lead to better pricing.
#
# **Negative Growth:** Relying too much on SCMS risks disruptions. If issues arise with them, it could hurt operations. Diversifying vendors could reduce this risk.

# %% [markdown]
# Chart - 7

# %%
import pandas as pd

fed_ex_raw = pd.read_excel("fedex.xlsx")

# %%
fed_ex_curated = fed_ex_raw.copy()

# %%
fed_ex_curated['Weight (Kilograms)'].dtype
# Out:
# dtype('O')

# %%
# Check a few values first
fed_ex_curated['Weight (Kilograms)'].head(10)
# Out:
# 0                       13
# 1                      358
# 2                      171
# 3                     1855
# 4                     7590
# 5                      504
# 6                      328
# 7                     1478
# 8    See ASN-93 (ID#:1281)
# 9                      643
# Name: Weight (Kilograms), dtype: object

# %%
fed_ex_curated['Weight (Kilograms)'] = pd.to_numeric(
    fed_ex_curated['Weight (Kilograms)'],
    errors='coerce'
)

# %%
fed_ex_curated['Weight (Kilograms)'].isna().sum()
# Out:
# np.int64(3952)

# %%
fed_ex_curated = fed_ex_curated.dropna(subset=['Weight (Kilograms)'])

# %%
avg_weights = fed_ex_curated.groupby('Shipment Mode')['Weight (Kilograms)'].mean()

# %%
import seaborn as sns

palette = sns.color_palette("Set2")

# %%
# Chart - 7: Average Shipment Weight by Shipping Method
fig, ax = plt.subplots(1, 1, figsize=(12, 7))

# Calculate average weight by shipment mode
avg_weights = fed_ex_curated.groupby('Shipment Mode')['Weight (Kilograms)'].mean().sort_values(ascending=False)
shipment_modes = avg_weights.index.tolist()
average_weights = avg_weights.values.tolist()

# Create bar plot with enhanced styling
bars = sns.barplot(data=fed_ex_curated, x='Shipment Mode', y='Weight (Kilograms)',
                   estimator='mean', palette=palette, order=shipment_modes,
                   alpha=0.8, edgecolor='black', linewidth=1)

# Add value labels on top of each bar
for i, (mode, avg_weight) in enumerate(zip(shipment_modes, average_weights)):
    plt.text(i, avg_weight + 0.5, f'{avg_weight:.1f} kg',
             ha='center', va='bottom', fontweight='bold', fontsize=11)

# Customize titles and labels for better understanding
plt.title('Average Shipment Weight by Shipping Method\n', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Shipping Method', fontsize=12, fontweight='bold', labelpad=10)
plt.ylabel('Average Weight (Kilograms)', fontsize=12, fontweight='bold', labelpad=10)

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45, ha='right')

# Add grid for easier value reading
plt.grid(axis='y', alpha=0.3, linestyle='--')

# Remove spines for cleaner look
sns.despine(left=True)

# Calculate additional insights
total_shipments = len(fed_ex_curated)
heaviest_mode = shipment_modes[0]
lightest_mode = shipment_modes[-1]
weight_ratio = average_weights[0] / average_weights[-1]

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart clearly shows the average weight of shipments for different transport modes, making it easy to compare them.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Air transport handles lighter shipments (1000 to 2000 kg), while trucks average 6500 kg, and ocean and Air Charter modes carry heavier loads (around 6800 kg to 7000 kg).

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:** Businesses can optimize shipping methods based on weight, leading to cost savings and better delivery efficiency.
#
# **Negative Impact:**Overusing air transport for lighter goods may increase costs, reducing overall profitability.

# %% [markdown]
# Chart - 8

# %%
# Chart - 8: Average Delivery Delay by Shipping Method

fig, ax = plt.subplots(1, 1, figsize=(12, 7))

# Calculate average delay days by shipment mode
fed_ex_curated['Delay_Days'] = (fed_ex_curated['Delivered to Client Date'] - fed_ex_curated['Scheduled Delivery Date']).dt.days
avg_delays = fed_ex_curated.groupby('Shipment Mode')['Delay_Days'].mean().sort_values(ascending=False)
shipment_modes = avg_delays.index.tolist()
average_delays = avg_delays.values.tolist()

# Create bar plot with enhanced styling
bars = sns.barplot(x='Shipment Mode', y='Delay_Days', data=fed_ex_curated, palette=palette,
                   order=shipment_modes, estimator='mean',
                   alpha=0.8, edgecolor='black', linewidth=1)

# Add value labels on top of each bar (color based on positive/negative delay)
for i, (mode, avg_delay) in enumerate(zip(shipment_modes, average_delays)):
    color = 'red' if avg_delay > 0 else 'green'
    label_text = f'+{avg_delay:.1f} days' if avg_delay > 0 else f'{avg_delay:.1f} days'
    plt.text(i, avg_delay + (0.1 if avg_delay >= 0 else -0.3), label_text,
             ha='center', va='bottom' if avg_delay >= 0 else 'top',
             fontweight='bold', fontsize=11, color=color)

# Customize titles and labels for better understanding
plt.title('Average Delivery Performance by Shipping Method\n', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Shipping Method', fontsize=12, fontweight='bold', labelpad=10)
plt.ylabel('Average Delay Days\n(Positive = Late, Negative = Early)', fontsize=12, fontweight='bold', labelpad=10)

# Add horizontal line at zero for reference
plt.axhline(y=0, color='black', linestyle='-', linewidth=1, alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Add grid for easier value reading
plt.grid(axis='y', alpha=0.3, linestyle='--')

# Remove spines for cleaner look
sns.despine(left=True)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot effectively displays the average delivery delays across different shipment modes, allowing for straightforward comparisons between them. It visually highlights differences in performance, making it easier to identify which modes are more reliable.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Air shipments have minimal delays, indicating they are generally on time. Truck shipments experience moderate delays of about 10 days.
#
# Air charters face the most significant delays, exceeding 15 days, suggesting they may be the least reliable.
#
# Ocean transport shows delays just under 5 days, indicating moderate reliability.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**: Understanding the reliability of different shipment modes can guide operational decisions. For example, businesses can prioritize standard air shipments for timely deliveries, improving customer satisfaction and trust.
#
# **Negative Impact**: The significant delays associated with air charters could lead to customer dissatisfaction, potentially harming business relationships and revenue. If air charters are promoted for urgent shipments despite their unreliability, it could result in negative customer experiences and loss of business.

# %% [markdown]
# Chart - 9

# %% [markdown]
# fed_ex_curated['Shipment_Date'].head(10)

# %%
fed_ex_curated.columns.tolist()
# Out:
# ['ID',
#  'Project Code',
#  'PQ #',
#  'PO / SO #',
#  'ASN/DN #',
#  'Country',
#  'Managed By',
#  'Fulfill Via',
#  'Vendor INCO Term',
#  'Shipment Mode',
#  'PQ First Sent to Client Date',
#  'PO Sent to Vendor Date',
#  'Scheduled Delivery Date',
#  'Delivered to Client Date',
#  'Delivery Recorded Date',
#  'Product Group',
#  'Sub Classification',
#  'Vendor',
#  'Item Description',
#  'Molecule/Test Type',
#  'Brand',
#  'Dosage',
#  'Dosage Form',
#  'Unit of Measure (Per Pack)',
#  'Line Item Quantity',
#  'Line Item Value',
#  'Pack Price',
#  'Unit Price',
#  'Manufacturing Site',
#  'First Line Designation',
#  'Weight (Kilograms)',
#  'Freight Cost (USD)',
#  'Line Item Insurance (USD)',
#  'Delay_Days']

# %%
fed_ex_curated[
    ['PQ First Sent to Client Date',
     'Scheduled Delivery Date',
     'Delivered to Client Date']
].head(10)
# Out:
#    PQ First Sent to Client Date Scheduled Delivery Date  \
# 0                Pre-PQ Process              2006-06-02
# 1                Pre-PQ Process              2006-11-14
# 2                Pre-PQ Process              2006-08-27
# 3                Pre-PQ Process              2006-09-01
# 4                Pre-PQ Process              2006-08-11
# 5                Pre-PQ Process              2006-09-28
# 6                Pre-PQ Process              2007-01-08
# 7                Pre-PQ Process              2006-11-24
# 9                Pre-PQ Process              2007-01-30
# 10               Pre-PQ Process              2007-02-16
#
#    Delivered to Client Date
# 0                2006-06-02
# 1                2006-11-14
# 2                2006-08-27
# 3                2006-09-01
# 4                2006-08-11
# 5                2006-09-28
# 6                2007-01-08
# 7                2006-11-24
# 9                2007-01-30
# 10               2007-02-16

# %%
fed_ex_curated.iloc[0]
# Out:
# ID                                                                              1
# Project Code                                                           100-CI-T01
# PQ #                                                               Pre-PQ Process
# PO / SO #                                                                  SCMS-4
# ASN/DN #                                                                    ASN-8
# Country                                                              C魌e d'Ivoire
# Managed By                                                               PMO - US
# Fulfill Via                                                           Direct Drop
# Vendor INCO Term                                                              EXW
# Shipment Mode                                                                 Air
# PQ First Sent to Client Date                                       Pre-PQ Process
# ...

# %%
fed_ex_curated.iloc[0]
# Out:
# ID                                                                              1
# Project Code                                                           100-CI-T01
# PQ #                                                               Pre-PQ Process
# PO / SO #                                                                  SCMS-4
# ASN/DN #                                                                    ASN-8
# Country                                                              C魌e d'Ivoire
# Managed By                                                               PMO - US
# Fulfill Via                                                           Direct Drop
# Vendor INCO Term                                                              EXW
# Shipment Mode                                                                 Air
# PQ First Sent to Client Date                                       Pre-PQ Process
# ...

# %%
import pandas as pd

# Convert to datetime. Invalid values like "Pre-PQ Process" become NaT.
fed_ex_curated['PQ First Sent to Client Date'] = pd.to_datetime(
    fed_ex_curated['PQ First Sent to Client Date'],
    errors='coerce'
)

fed_ex_curated['Scheduled Delivery Date'] = pd.to_datetime(
    fed_ex_curated['Scheduled Delivery Date'],
    errors='coerce'
)

# Use Scheduled Delivery Date when PQ First Sent to Client Date is missing
fed_ex_curated['Shipment_Date'] = (
    fed_ex_curated['PQ First Sent to Client Date']
    .fillna(fed_ex_curated['Scheduled Delivery Date'])
)

# %%
fed_ex_curated['Shipment_Date'].head()
# Out:
# 0   2006-06-02
# 1   2006-11-14
# 2   2006-08-27
# 3   2006-09-01
# 4   2006-08-11
# Name: Shipment_Date, dtype: datetime64[ns]

# %%
# Chart - 9: Monthly Shipment Volume Trend Over Time
fig, ax = plt.subplots(figsize=(14, 8))

# Prepare time series data
fed_ex_curated['Shipment_Date'] = fed_ex_curated['PQ First Sent to Client Date'].fillna(fed_ex_curated['Scheduled Delivery Date'])
shipments_over_time = fed_ex_curated.resample('M', on='Shipment_Date').size()

# Calculate trend statistics
total_months = len(shipments_over_time)
total_shipments = shipments_over_time.sum()
avg_monthly = shipments_over_time.mean()
max_month = shipments_over_time.idxmax()
max_shipments = shipments_over_time.max()
min_month = shipments_over_time.idxmin()
min_shipments = shipments_over_time.min()

# Create area chart with enhanced styling
ax.fill_between(shipments_over_time.index, shipments_over_time.values,
                color='#ff6600', alpha=0.4, label='Monthly Volume')
ax.plot(shipments_over_time.index, shipments_over_time.values,
        color='#e65c00', linewidth=3, marker='o', markersize=4, label='Trend Line')

# Add moving average for smoother trend visualization
rolling_avg = shipments_over_time.rolling(window=3, center=True).mean()
ax.plot(rolling_avg.index, rolling_avg.values, color='#000000', linewidth=2,
        linestyle='--', label='3-Month Moving Avg')

# Highlight peak and trough months
ax.axvline(x=max_month, color='red', linestyle=':', alpha=0.7,
           label=f'Peak: {max_month.strftime("%b %Y")}')
ax.axvline(x=min_month, color='blue', linestyle=':', alpha=0.7,
           label=f'Low: {min_month.strftime("%b %Y")}')

# Customize titles and labels
plt.title('Monthly Shipment Volume Trend Analysis\n',
          fontsize=16, fontweight='bold', pad=20, color='#2E4053')
plt.xlabel('Time (Months)', fontsize=12, fontweight='bold', labelpad=10)
plt.ylabel('Number of Shipments', fontsize=12, fontweight='bold', labelpad=10)

# Format x-axis dates
ax.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%b %Y'))
plt.xticks(rotation=45, ha='right')

# Add grid for better readability
plt.grid(axis='y', alpha=0.3, linestyle='--')

# Add legend
plt.legend(loc='upper left', fontsize=10)

# Remove spines for cleaner look
sns.despine()

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# Chart - 10

# %%
import matplotlib.ticker as mtick

# %%
# Chart - 10: Distribution of Line Item Values by Shipping Method
fig, ax = plt.subplots(figsize=(12, 8))

# Calculate statistics for each shipment mode
value_stats = fed_ex_curated.groupby('Shipment Mode')['Line Item Value'].describe()
shipment_modes = value_stats.index.tolist()

# Create boxplot without outliers for cleaner visualization
boxplot = sns.boxplot(x='Shipment Mode', y='Line Item Value', data=fed_ex_curated,
                     palette=palette, showfliers=False, width=0.7)

# Calculate and add mean markers for each group
means = fed_ex_curated.groupby('Shipment Mode')['Line Item Value'].mean()
for i, mode in enumerate(shipment_modes):
    ax.plot(i, means[mode], 'o', color='red', markersize=8, label='Mean' if i == 0 else "")

# Customize titles and labels for better understanding
plt.title('Distribution of Shipment Values by Shipping Method\n(Outliers Excluded)\n',
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Shipping Method', fontsize=12, fontweight='bold', labelpad=10)
plt.ylabel('Line Item Value (USD)', fontsize=12, fontweight='bold', labelpad=10)

# Format y-axis as currency
ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('${x:,.0f}'))

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Add grid for easier value reading
plt.grid(axis='y', alpha=0.3, linestyle='--')

# Add legend for mean markers
plt.legend(['Mean Value'], loc='upper right', fontsize=10)

# Calculate key insights
highest_avg_value_mode = means.idxmax()
highest_avg_value = means.max()
lowest_avg_value_mode = means.idxmin()
lowest_avg_value = means.min()
value_ratio = highest_avg_value / lowest_avg_value

# Add statistical annotations
text_props = dict(boxstyle="round,pad=0.3", facecolor="yellow", alpha=0.7)
stats_text = f'Key Statistics:\n\n'
stats_text += f'Highest Avg: ${highest_avg_value:,.0f}\n({highest_avg_value_mode})\n'
stats_text += f'Lowest Avg: ${lowest_avg_value:,.0f}\n({lowest_avg_value_mode})\n'
stats_text += f'Ratio: {value_ratio:.1f}x difference'

ax.text(0.02, 0.98, stats_text, transform=ax.transAxes, fontsize=10,
        verticalalignment='top', bbox=text_props)

# Remove spines for cleaner look
sns.despine()

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The box plot was chosen because it effectively displays the distribution of line item values across different shipment modes. It highlights median values, variability, and potential outliers, providing a clear comparison of how different modes perform in terms of item volume.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights reveal that FedEx has the highest median line item value, indicating it is a preferred option for shipping items. The Truck mode shows a smaller interquartile range, suggesting more consistency in the number of items shipped, while the "Other" category contains outliers, hinting at occasional high-volume shipments that may need further investigation.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:** The insights can guide the company in enhancing its logistics strategy by focusing on the more profitable shipment modes, such as FedEx, thus optimizing resource allocation and improving overall profitability.
#
# **Negative Impact:** The presence of outliers in the "Other" category could indicate erratic shipping patterns, leading to unexpected costs or operational challenges. If not addressed, this inconsistency may harm customer satisfaction and potentially result in lost business opportunities.

# %% [markdown]
# Chart - 11

# %%
fed_ex_curated['Freight Cost (USD)'] = pd.to_numeric(
    fed_ex_curated['Freight Cost (USD)'],
    errors='coerce'
)

# %%
fed_ex_curated_clean = fed_ex_curated.dropna(subset=[
    'Weight (Kilograms)',
    'Freight Cost (USD)'
])

# %%
fig, ax = plt.subplots(figsize=(5, 3))

sns.scatterplot(
    x='Weight (Kilograms)',
    y='Freight Cost (USD)',
    data=fed_ex_curated_clean,
    s=50,
    alpha=0.7,
    color='#4d148c',
    ax=ax
)

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a scatter plot because it effectively displays the relationship between freight cost and weight, allowing for a clear visualization of trends, variability, and potential outliers.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?
#
# The scatter plot shows a general trend where freight costs increase with the weight of shipments. However, there is notable variability, suggesting that other factors like shipment mode and item type also play a role in determining freight costs. Additionally, some outliers indicate unusual shipments or potential data errors.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact: **The insights can help businesses optimize shipping strategies by understanding how weight influences costs, enabling more accurate pricing and better budget planning.
#
# **Negative Impact:** If businesses overlook the variability and rely solely on weight to predict costs, they may miscalculate shipping expenses, potentially leading to budget overruns and reduced profitability. Outliers could also indicate underlying issues that need addressing to avoid financial losses.

# %% [markdown]
# Chart - 12

# %%
import numpy as np

# %%
# Chart - 12: Top 10 Countries by Total Freight Costs
fig, ax = plt.subplots(1, 1, figsize=(14, 8))

# Prepare data - clean and aggregate freight costs
fed_ex_curated['Freight Cost (USD)'] = fed_ex_curated['Freight Cost (USD)'].fillna(0)
fed_ex_curated['Freight Cost (USD)'] = np.where(np.isfinite(fed_ex_curated['Freight Cost (USD)']),fed_ex_curated['Freight Cost (USD)'], 0)
fed_ex_curated['Freight Cost (USD)'] = fed_ex_curated['Freight Cost (USD)'].astype(int)

# Get top 10 countries by total freight cost
top_10_countries = fed_ex_curated.groupby('Country')['Freight Cost (USD)'].sum().nlargest(10).reset_index()
top_10_countries = top_10_countries.sort_values('Freight Cost (USD)', ascending=True)  # Sort for horizontal bars

# Create horizontal bar plot for better readability
bars = sns.barplot(x='Freight Cost (USD)', y='Country', data=top_10_countries,
                  palette=palette, alpha=0.8, edgecolor='black', linewidth=1)

# Add value labels on each bar
for i, (country, cost) in enumerate(zip(top_10_countries['Country'], top_10_countries['Freight Cost (USD)'])):
    plt.text(cost + (cost * 0.01), i, f'${cost:,.0f}',
             ha='left', va='center', fontweight='bold', fontsize=10)

# Customize titles and labels for better understanding
plt.title('Top 10 Countries by Total Freight Costs\n', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Total Freight Cost (USD)', fontsize=12, fontweight='bold', labelpad=10)
plt.ylabel('Country', fontsize=12, fontweight='bold', labelpad=10)

# Format x-axis as currency
ax.xaxis.set_major_formatter(mtick.StrMethofed_ex_rawormatter('${x:,.0f}'))

# Add grid for easier value reading
plt.grid(axis='x', alpha=0.3, linestyle='--')

# Remove spines for cleaner look
sns.despine(left=True)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3310/3453025099.py in <cell line: 0>()
#      26
#      27 # Format x-axis as currency
# ---> 28 ax.xaxis.set_major_formatter(mtick.StrMethofed_ex_rawormatter('${x:,.0f}'))
#      29
#      30 # Add grid for easier value reading
#
# AttributeError: module 'matplotlib.ticker' has no attribute 'StrMethofed_ex_rawormatter'

# %% [markdown]
# 1. Why did you pick the specific chart?
#
#
# I chose a bar chart because it effectively displays the total freight costs for the top 10 countries, making it easy to compare their expenditures visually.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that Nigeria has the highest freight costs, followed by zambia and côte d'ivoire. It highlights significant differences in freight spending among these countries, with Nigeria standing out as the highest payer.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:** Understanding which countries have the highest freight costs can help businesses target these markets for potential partnerships or increased service offerings.
#
# **Negative Impact:** If a business relies heavily on high-cost countries like Nigeria, it may face challenges in maintaining profitability. This reliance on expensive shipping could hinder growth if not managed effectively.

# %% [markdown]
# Chart - 13

# %%
print(type(fed_ex_curated))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Chart - 13: Freight Cost Distribution by Shipping Method
fig, ax = plt.subplots(figsize=(12, 8))

# Calculate statistics for each shipment mode
cost_stats = fed_ex_curated.groupby('Shipment Mode')['Freight Cost (USD)'].describe()
shipment_modes = cost_stats.index.tolist()

# Create boxplot without outliers for cleaner visualization
boxplot = sns.boxplot(x='Shipment Mode', y='Freight Cost (USD)', data=fed_ex_curated,
                     palette=palette, showfliers=False, width=0.7)

# Calculate and add mean markers for each group
means = fed_ex_curated.groupby('Shipment Mode')['Freight Cost (USD)'].mean()
for i, mode in enumerate(shipment_modes):
    ax.plot(i, means[mode], 'o', color='red', markersize=8, label='Mean' if i == 0 else "")

# Customize titles and labels for better understanding
plt.title('Freight Cost Distribution by Shipping Method\n(Outliers Excluded)\n',
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Shipping Method', fontsize=12, fontweight='bold', labelpad=10)
plt.ylabel('Freight Cost (USD)', fontsize=12, fontweight='bold', labelpad=10)

# Format y-axis as currency
ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('${x:,.0f}'))

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Add grid for easier value reading
plt.grid(axis='y', alpha=0.3, linestyle='--')

# Calculate key insights
highest_cost_mode = means.idxmax()
highest_avg_cost = means.max()
lowest_cost_mode = means.idxmin()
lowest_avg_cost = means.min()
cost_ratio = highest_avg_cost / lowest_avg_cost

# Add statistical annotations
text_props = dict(boxstyle="round,pad=0.3", facecolor="yellow", alpha=0.7)
stats_text = f'Key Cost Insights:\n'
stats_text += f'Most Expensive: ${highest_avg_cost:,.0f}\n({highest_cost_mode})\n'
stats_text += f'Most Affordable: ${lowest_avg_cost:,.0f}\n({lowest_cost_mode})\n'
stats_text += f'Price Difference: {cost_ratio:.1f}x'

ax.text(0.02, 0.98, stats_text, transform=ax.transAxes, fontsize=10,
        verticalalignment='top', bbox=text_props)

# Calculate cost efficiency metrics
median_costs = fed_ex_curated.groupby('Shipment Mode')['Freight Cost (USD)'].median()
cost_variability = fed_ex_curated.groupby('Shipment Mode')['Freight Cost (USD)'].std()

# Remove spines for cleaner look
sns.despine()

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a box plot because it clearly compares freight costs across different shipment modes, showing the median, consistency, and any outliers.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The box plot shows that Air Charter has the highest median freight cost, followed by Ocean and Air . Air has more consistent costs, while Ocean has occasional high outlier costs.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact: **The insights help businesses select cost-effective shipping options and manage budgets better.
#
# **Negative Impact:** Outliers in Truck could lead to unexpected high costs, which might hurt profit margins and customer satisfaction, potentially affecting growth

# %% [markdown]
# Chart - 14 - Correlation Heatmap

# %%
# Chart 14: Correlation Heatmap

import matplotlib.pyplot as plt
import seaborn as sns

# Select only numerical columns
numeric_df = fed_ex_curated.select_dtypes(include=['number'])

# Compute correlation matrix
correlation_matrix = numeric_df.corr()

# Create heatmap
plt.figure(figsize=(12, 8))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5,
    square=True,
    cbar=True
)

plt.title('Correlation Heatmap of Numerical Features', fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# A Correlation Heatmap was chosen because it is one of the most effective ways to visualize the relationships between multiple numerical variables at the same time.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The correlation heatmap reveals the strength and direction of relationships between the numerical variables in the dataset. It shows that some variables, such as Line Item Value, Unit Price, and Freight Cost (USD), have a positive correlation, indicating that higher-value shipments generally incur higher freight costs.

# %% [markdown]
# Chart - 15 - Pair Plot

# %%
# Chart 15: Pair Plot

import seaborn as sns
import matplotlib.pyplot as plt

# Select important numerical columns
pairplot_df = fed_ex_curated[[
    'Freight Cost (USD)',
    'Line Item Value',
    'Unit Price',
    'Line Item Quantity',
    'Weight (Kilograms)'
]].copy()

# Remove missing values
pairplot_df = pairplot_df.dropna()

# Create pair plot
sns.pairplot(
    pairplot_df,
    diag_kind='hist',
    corner=True
)

plt.suptitle('Pair Plot of Key Numerical Variables', y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# A pairplot is useful because:
#
# 1. It shows relationships between all variables at once
# Instead of plotting one pair at a time, it creates a full grid of comparisons (feature vs feature).

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Relationships (Correlation) between variables
#
# You can quickly see:
#
# Strong positive correlation → both variables increase together (points form an upward line)
# Strong negative correlation → one increases while other decreases
# No correlation → scattered points

# %% [markdown]
# 5. Solution to Business Objective

# %% [markdown]
# What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# Based on the visualizations and analysis performed in the FedEx Logistics Performance Analysis,here are the key insights and actionable solutions to address the stated business objectives:
#
# **1. Improve Delivery Efficiency:**
#
# **Insights from Visualizations:**
#
# *   Shipment Mode Analysis: Certain shipment modes (e.g., Air) show higher average weights and freight costs but also experience more delays.
# *   Lead Time Analysis: Significant variations in lead times across countries and shipment modes indicate inefficiencies.
# *   Vendor Performance: Some vendors consistently have longer lead times or higher freight costs.
#
# **Solutions:**
#
# *   Optimize Shipment Modes: For high-weight shipments, consider shifting from Air to Ocean or Truck where feasible to reduce costs and improve efficiency.
# *   Vendor Collaboration: Work with vendors showing consistent delays to streamline their processes. Implement performance-based contracts to incentivize timely deliveries.
# *   Route Optimization: Use data to identify common routes with delays and optimize logistics routes or switch carriers for those lanes.
#
# **2. Enhance Customer Satisfaction:**
#
# **Insights from Visualizations:**
#
# *   Delivery Delays: Certain countries and shipment modes have higher incidences of delays.
# *   Cost vs. Service: High freight costs do not always correlate with faster deliveries, leading to customer dissatisfaction.
# *   Geographic Concentration: Some regions experience more delays and higher costs, impacting customer satisfaction.
#
# **Solutions:**
#
# *   Proactive Communication: Implement real-time tracking and notifications for customers to manage expectations during delays.
# *   Service Level Agreements (SLAs): Define clear SLAs with vendors and carriers to ensure consistent service quality.
# *   Customer Feedback Loop: Regularly collect and analyze customer feedback to identify pain points and address them promptly.
#
# **3. Identify Bottlenecks:**
#
# **Insights from Visualizations:**
#
# *   Shipment Delays: Delays are more common in specific countries and with certain vendors.
# *   Process Inefficiencies: "Date Not Captured" entries in PO Sent to Vendor Date indicate gaps in data recording, leading to process ambiguities.
# *   Freight Cost Variability: Inconsistent freight costs across similar shipments suggest inefficiencies in carrier selection or negotiation.
#
# **Solutions:**
#
# *   Data Integrity: Implement mandatory data entry fields to capture key dates (e.g., PO Sent to Vendor Date) to improve tracking and accountability.
# *   Root Cause Analysis: Conduct detailed investigations into high-delay regions and vendors to identify specific bottlenecks (e.g., customs clearance, carrier reliability).
# *   Process Automation: Automate data capture and tracking to reduce manual errors and improve visibility into the shipment lifecycle.
#
# **4. Streamline Processes:**
#
# **Insights from Visualizations:**
#
# *   Vendor Consolidation: A large number of vendors are used, but a few account for the majority of shipments. This fragmentation can lead to inefficiencies.
# *   Shipment Mode Over-Reliance: Heavy reliance on Air shipments for certain routes may not be cost-effective or efficient.
# *   Inconsistent Data: Missing data in key columns (e.g., Shipment Mode, Dosage) indicates gaps in process adherence.
#
# **Solutions:**
#
# *   Vendor Rationalization: Reduce the number of vendors and focus on those with the best performance in terms of cost, timeliness, and reliability.
# *   Mode Diversification: Develop a balanced shipment mode strategy based on urgency, cost, and reliability. Use predictive analytics to recommend the optimal mode for each shipment.
# *   Standard Operating Procedures (SOPs): Establish clear SOPs for data entry, shipment mode selection, and vendor management to ensure consistency.
#
# **5. Ensure Timely Deliveries:**
#
# **Insights from Visualizations:**
#
# *   Lead Time Variability: Significant differences in lead times across countries and shipment modes.
# *   Scheduled vs. Actual Delivery: Discrepancies between scheduled and actual delivery dates indicate poor planning or execution.
#
# **Solutions:**
#
# *   Predictive Analytics: Use historical data to predict lead times more accurately and set realistic schedules.
# *   Buffer Time: Incorporate buffer times for routes and vendors with historically variable lead times.
# *   Performance Monitoring: Continuously monitor on-time delivery metrics and take corrective actions for underperforming vendors or routes.
#
# **6. Ensure Cost-Effective Deliveries:**
#
# **Insights from Visualizations:**
#
# *   High Freight Costs: Air shipments have disproportionately high freight costs compared to other modes.
# *   Vendor Cost Variability: Significant cost variations for similar shipments from different vendors.
# *   Insurance Costs: Line item insurance costs are often missing or inconsistent, suggesting missed cost-saving opportunities.
#
# **Solutions:**
#
# *   Negotiate Contracts: Leverage volume discounts by consolidating shipments with fewer carriers and vendors.
# *   Mode Selection Algorithm: Develop an algorithm to automatically select the most cost-effective shipment mode based on weight, urgency, and destination.
# *   Insurance Optimization: Analyze insurance costs and consider self-insurance for low-value shipments or negotiate better rates with insurers.

# %% [markdown]
# **Conclusion**

# %% [markdown]
# This analysis underscores the interplay between cost, reliability, and operational efficiency in FedEx's logistics network. By leveraging data-driven insights, FedEx can enhance customer satisfaction, reduce costs, and maintain a competitive edge in the global logistics landscape. The visualizations and patterns identified provide a robust foundation for continuous improvement and strategic decision-making.
